# %% [markdown]
# # Problems 2 - Basic Data Manipulation with Python

# %% [markdown]
# ## 1.1 Grading students

# %% [markdown]
# You have been given a list of students in a CSV (Comma Separated Values) file, along with the evaluation scores for a series of works they have submitted. The table of data looks like this:
#
# | student_id                           | Score  | Submission_Time  |
# | ------------------------------------ |:------:| ----------------:|
# | B73F2C11-70F0-E37D-8B10-1D20AFED50B1 | 92.7   | 02/11/2015 06:55 |
# | 98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1 | 86.8   | 29/11/2015 14:57 |
# | D0F62040-CEB0-904C-F563-2F8620916C4E | 85.5   | 09/01/2016 05:36 |
# | FFDF2B2C-F514-EF7F-6538-A6A53518E9DC | 86.0   | 30/04/2016 06:50 |
# | 5ECBEEB6-F1CE-80AE-3164-E45E99473FB4 | 64.8   | 13/12/2015 17:06 |
# | ... | ... | ... |
#
#
# In this exercise we will import and manipulate this data. A lot of code is already given. When code is asked for, this is indicated <font color=blue>in blue</font>.

# %% [markdown]
# <br>
#
# First, let's get the data in from a csv file

# %%
import csv
import numpy as np
import pandas as pd
from datetime import datetime


with open('grades.csv') as csvfile:
    grades = list(csv.DictReader(csvfile))

print('We have imported {0} entries'.format(len(grades))) #Let's print out the number of entries (rows) we have read

grades[:4] # The first four dictionaries in our list, corresponding to the first three lines

# %% [markdown]
# <br>
#
# **Exercise 1**: As we learnt in the previous lab, use list comprehension to store 'student_id', 'Score', and 'Submission_Time' within lists and use these new lists as arguments  to create  similar arrays
#
# <font color=blue>Read the CSV file and store each column in a separate array:

# %%
ids = [] # Let´s use list comprehension to store the id´s 
scores = [] # Let´s use list comprehension to store the scores 
times = [] # Let´s use list comprehension to store the submission time

# %% [markdown]
# <br>
#
# **Exercise 2**: Basic operations with arrays
#
# <font color=blue> Get the array of scores and calculate Maximum score, Minimum score, Average score :

# %% [markdown]
# <br>
#
# **Exercise 3**: Filtering
#
# <font color=blue>Filter the score array using a condition to identify how many fail the test (score < 50)

# %%
failed_students=   # Use a condition to filter the score array to leave only those who fail and then count the result

# %% [markdown]
# <br>
#
# **Exercise 4**: Combining arrays
#
# <font color=blue> Use the functions reviewed in class to stack the 3 uni dimensinal arrays created (ids,scores,times)

# %%
grades=  # Use the functions reviewed in classs to create a n-dimensional array grade

# %% [markdown]
# <br>
#
# **Exercise 5**: Create a histogram
#
# <font color=blue> Make a histogram (using arrays) of how many students fall into each score range (e.g., 0–59, 60–69, 70–79, 80–89, 90–100).

# %% [markdown]
# > *Hint : Use a list of bins and use it as argument in the hist function bins = [0, 60, 70, 80, 90, 101]
